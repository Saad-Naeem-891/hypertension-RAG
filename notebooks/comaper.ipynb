# %%
# %cd /home/saad-naeem/Projects/Plod_presure_Hackathon
# %run notebooks/compare_evaluation_experiments.py
# Out:
# /home/saad-naeem/Projects/Plod_presure_Hackathon
# Project root: /home/saad-naeem/Projects/Plod_presure_Hackathon
# Successful runs loaded: 9
# Runs included in charts: 9
#                         run_id                   started_at_utc  \
# 0  eval_20260818T083844334447Z 2026-08-18 08:38:44.334447+00:00
# 1  eval_20260818T083902963130Z 2026-08-18 08:39:02.963130+00:00
# 2  eval_20260818T090047616681Z 2026-08-18 09:00:47.616681+00:00
# 3  eval_20260818T092943926378Z 2026-08-18 09:29:43.926378+00:00
# 4  eval_20260818T093112183351Z 2026-08-18 09:31:12.183351+00:00
# 5  eval_20260818T100705095769Z 2026-08-18 10:07:05.095769+00:00
# 6  eval_20260818T104719715380Z 2026-08-18 10:47:19.715380+00:00
# 7  eval_20260818T105423831848Z 2026-08-18 10:54:23.831848+00:00
# 8  eval_20260818T110227045376Z 2026-08-18 11:02:27.045376+00:00
#
#                       embedding_model         retriever_type  candidate_k  \
# 0      intfloat/multilingual-e5-small  hybrid_dense_bm25_rrf           20
# ...
